# %%
import pandas as pd

# %%
simpsons = pd.read_html('https://es.wikipedia.org/wiki/Anexo:Episodios_de_Los_Simpson')

# %%
simpons
# Out:
# [    0                                                  1   2
#  0 NaN  Este artículo se refiere o está relacionado co... NaN,
#       #     Episodios Audiencia(en millonesde personas)                Discos  \
#       # #.1 Episodios Audiencia(en millonesde personas)                Discos
#  0  NaN   1        13                              14.5                     3
#  1  NaN   2        22                              12.2                     4
#  2  NaN   3        24                              12.0                     4
#  3  NaN   4        22                              12.1                     4
#  4  NaN   5        22                              10.5                     4
#  5  NaN   6        25                               9.0                     4
#  6  NaN   7        25                               8.0                     4
#  7  NaN   8        25                               8.6                     4
# ...

# %%
simpsons[3]
# Out:
#     N.º en serie  N.º en temp.  \
# 0             14             1
# 1             15             2
# 2             16             3
# 3             17             4
# 4             18             5
# 5             19             6
# 6             20             7
# 7             21             8
# 8             22             9
# 9             23            10
# 10            24            11
# 11            25            12
# 12            26            13
# 13            27            14
# 14            28            15
# 15            29            16
# 16            30            17
# 17            31            18
# 18            32            19
# 19            33            20
# 20            34            21
# 21            35            22
#
#                                                Título  \
# 0                                  «Bart Gets an "F"»
# 1                               «Simpson and Delilah»
# 2                               «Treehouse of Horror»
# ...
